# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenTang021205/AC6007-AY2025/blob/main/w1_dbs_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import joblib
model=joblib.load("/content/dbs.jl")
print(model.coef_,model.intercept_)
# Out:
# [[-50.60094302]] [90.22858515]

# %%
print(model.predict([[1.3]]))
# Out:
# [[24.44735922]]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
